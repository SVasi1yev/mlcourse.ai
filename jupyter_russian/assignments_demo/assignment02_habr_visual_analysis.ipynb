# %% [markdown]
# <img src="../../img/ods_stickers.jpg">
#
# ## <center> [mlcourse.ai](https://mlcourse.ai) – открытый курс OpenDataScience по машинному обучению
#
# Автор материала: Екатерина Демидова, Data Scientist @ Segmento. Материал распространяется на условиях лицензии [Creative Commons CC BY-NC-SA 4.0](https://creativecommons.org/licenses/by-nc-sa/4.0/). Можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала.
# Автор материала:

# %% [markdown]
# # <center>Домашнее задание № 2 (демо). <br> Визуальный анализ данных о публикациях на Хабрахабре</center>
#
# **Заполните код в клетках и ответьте на вопросы в [веб-форме](https://docs.google.com/forms/d/1y8qj5iYpaVhczjWnZuHd5NRR_sdCGy3eTF5n-qPKknQ).**

# %%
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Загрузка и знакомство с данными
#
# Для работы вам понадобятся предобработанные данные нашего учебного конкурса на kaggle [«Прогноз популярности статьи на Хабре»](https://www.kaggle.com/c/howpop-habrahabr-favs). Скачайте [данные](https://drive.google.com/file/d/1nV2qV9otN3LnVSDqy95hvpJdb6aWtATk/view?usp=sharing) соревнования (данные были удалены с Kaggle ради организации последующего идентичного соревнования, так что тут ссылка на Google Drive).

# %%
# при необходимости поменяйте путь к данным
df = pd.read_csv("../../data/howpop_train.csv")

# %%
df.shape
# Out:
# (134137, 17)

# %%
df.head(3).T
# Out:
#                                                                0  \
# url                             https://habrahabr.ru/post/18284/
# domain                                              habrahabr.ru
# post_id                                                    18284
# published                                    2008-01-01 18:19:00
# author                                                    @Tapac
# flow                                                     develop
# polling                                                    False
# content_len                                                 4305
# title             Новогодний подарок блоггерам — WordPress 2.3.2
# comments                                                       0
# favs                                                           0
# views                                                        236
# votes_plus                                                     0
# votes_minus                                                    0
# views_lognorm                                          -0.792687
# favs_lognorm                                            -1.34407
# comments_lognorm                                        -2.43687
#
#                                                                   1  \
# url                                https://habrahabr.ru/post/18285/
# domain                                                 habrahabr.ru
# post_id                                                       18285
# published                                       2008-01-01 18:30:00
# author                                                   @DezmASter
# flow                                                         design
# polling                                                       False
# content_len                                                    7344
# title             Сумасшедшие яйца, или сервис для отслеживания ...
# comments                                                          1
# favs                                                              1
# views                                                           353
# votes_plus                                                        1
# votes_minus                                                       0
# views_lognorm                                             -0.485214
# favs_lognorm                                              -0.831946
# comments_lognorm                                           -1.87319
#
#                                                                   2
# url                                https://habrahabr.ru/post/18286/
# domain                                                 habrahabr.ru
# post_id                                                       18286
# published                                       2008-01-01 18:34:00
# author                                                   @DezmASter
# flow                                                         design
# polling                                                       False
# content_len                                                    8431
# title             Сумасшедшие яйца, или сервис для отслеживания ...
# comments                                                         47
# favs                                                             72
# views                                                          1200
# votes_plus                                                       45
# votes_minus                                                       5
# views_lognorm                                               0.44609
# favs_lognorm                                                1.79402
# comments_lognorm                                           0.574656

# %% [markdown]
# Избавимся сразу от переменных, названия которых заканчиваются на `_lognorm` (нужны для соревнования на Kaggle). Выберем их с помощью `filter()` и удалим `drop`-ом:

# %%
df.drop(
    filter(lambda c: c.endswith("_lognorm"), df.columns),
    axis=1,  # axis = 1: столбцы
    inplace=True,
)  # избавляет от необходимости сохранять датасет

# %%
df.describe().T
# Out:
#                 count           mean           std      min       25%  \
# post_id      134137.0  181307.054265  81766.350702  18284.0  115565.0
# content_len  134137.0    7516.929699   8724.771640      1.0    2179.0
# comments     134137.0      39.625994     62.398958      0.0       7.0
# favs         134137.0      71.999866    145.854135      0.0       8.0
# views        134137.0   16631.013084  31479.819691      3.0    2100.0
# votes_plus   133566.0      35.536888     42.461073      0.0      11.0
# votes_minus  133566.0       8.050035     11.398282      0.0       2.0
#
#                   50%       75%        max
# post_id      182666.0  257401.0   314088.0
# content_len    4949.0    9858.0   352471.0
# comments         19.0      48.0     2266.0
# favs             27.0      78.0     8718.0
# views          7600.0   18700.0  1730000.0
# votes_plus       22.0      45.0     1466.0
# votes_minus       5.0      10.0      445.0

# %%
df.describe(include=["object", "bool"]).T  # бинарные и категориальные переменные
# Out:
#             count  unique                                          top    freq
# url        134137  134137            https://habrahabr.ru/post/100961/       1
# domain     134137       2                                 habrahabr.ru   97048
# published  134137  130291                          2011-06-14 15:52:00      39
# author      97657   22077                                      @alizar    5292
# flow        97048       6                                      develop   53318
# polling    134137       2                                        False  129412
# title      134137  133628  Интересные события, произошедшие в выходные      56

# %%
# настройка внешнего вида графиков в seaborn
sns.set_style("dark")
sns.set_palette("RdBu")
sns.set_context(
    "notebook", font_scale=1.5, rc={"figure.figsize": (15, 5), "axes.titlesize": 18}
)

# %% [markdown]
# Столбец **`published`** (время публикации) содержит строки. Чтобы мы могли работать с этими данными как с датой/временем публикации, приведём их к типу `datetime`:

# %%
print(df.published.dtype)
df["published"] = pd.to_datetime(df.published, yearfirst=True)
print(df.published.dtype)
# Out:
# object
# datetime64[ns]

# %% [markdown]
# Создадим несколько столбцов на основе данных о времени публикации:

# %%
df["year"] = [d.year for d in df.published]
df["month"] = [d.month for d in df.published]
df["day"] = [d.day for d in df.published]

df["dayofweek"] = [d.isoweekday() for d in df.published]
df["hour"] = [d.hour for d in df.published]

# %%
df.T
# Out:
#                                                      0       \
# url                        https://habrahabr.ru/post/18284/
# domain                                         habrahabr.ru
# post_id                                               18284
# published                               2008-01-01 18:19:00
# author                                               @Tapac
# flow                                                develop
# polling                                               False
# content_len                                            4305
# title        Новогодний подарок блоггерам — WordPress 2.3.2
# comments                                                  0
# favs                                                      0
# views                                                   236
# votes_plus                                                0
# votes_minus                                               0
# year                                                   2008
# month                                                     1
# day                                                       1
# dayofweek                                                 2
# hour                                                     18
#
#                                                         1       \
# url                           https://habrahabr.ru/post/18285/
# domain                                            habrahabr.ru
# post_id                                                  18285
# published                                  2008-01-01 18:30:00
# author                                              @DezmASter
# flow                                                    design
# polling                                                  False
# content_len                                               7344
# title        Сумасшедшие яйца, или сервис для отслеживания ...
# comments                                                     1
# favs                                                         1
# views                                                      353
# votes_plus                                                   1
# votes_minus                                                  0
# year                                                      2008
# month                                                        1
# day                                                          1
# dayofweek                                                    2
# hour                                                        18
#
#                                                         2       \
# url                           https://habrahabr.ru/post/18286/
# domain                                            habrahabr.ru
# post_id                                                  18286
# published                                  2008-01-01 18:34:00
# author                                              @DezmASter
# flow                                                    design
# polling                                                  False
# content_len                                               8431
# title        Сумасшедшие яйца, или сервис для отслеживания ...
# comments                                                    47
# favs                                                        72
# views                                                     1200
# votes_plus                                                  45
# votes_minus                                                  5
# year                                                      2008
# month                                                        1
# day                                                          1
# dayofweek                                                    2
# hour                                                        18
#
#                                                      3       \
# url                        https://habrahabr.ru/post/18291/
# domain                                         habrahabr.ru
# post_id                                               18291
# published                               2008-01-02 01:32:00
# author                                             @Taoorus
# flow                                                 design
# polling                                               False
# content_len                                            5662
# title        Сглаживание шрифтов, и субпиксельная отрисовка
# comments                                                102
# favs                                                     36
# views                                                  5700
# votes_plus                                               72
# votes_minus                                               3
# year                                                   2008
# month                                                     1
# day                                                       2
# dayofweek                                                 3
# hour                                                      1
#
#                                        4       \
# url          https://geektimes.ru/post/18294/
# domain                           geektimes.ru
# post_id                                 18294
# published                 2008-01-02 14:34:00
# author                               @dennydo
# flow                                      NaN
# polling                                 False
# content_len                              3706
# title           Почему мне не нравится iPhone
# comments                                  230
# favs                                        6
# views                                    1400
# votes_plus                                 73
# votes_minus                                15
# year                                     2008
# month                                       1
# day                                         2
# dayofweek                                   3
# hour                                       14
#
#                                        5       \
# url          https://habrahabr.ru/post/18295/
# domain                           habrahabr.ru
# post_id                                 18295
# published                 2008-01-02 16:14:00
# author                                  @lvea
# flow                                  develop
# polling                                 False
# content_len                              3171
# title          Mobile2.0 Всеобщая доступность
# comments                                   22
# favs                                        1
# views                                     192
# votes_plus                                  9
# votes_minus                                 2
# year                                     2008
# month                                       1
# day                                         2
# dayofweek                                   3
# hour                                       16
#
#                                        6       \
# url          https://geektimes.ru/post/18306/
# domain                           geektimes.ru
# post_id                                 18306
# published                 2008-01-03 12:55:00
# author                               @abbasov
# flow                                      NaN
# polling                                 False
# content_len                               435
# title                      Modbook в действии
# comments                                   10
# favs                                        0
# views                                     301
# votes_plus                                  5
# votes_minus                                 1
# year                                     2008
# month                                       1
# day                                         3
# dayofweek                                   4
# hour                                       12
#
#                                        7       \
# url          https://habrahabr.ru/post/18311/
# domain                           habrahabr.ru
# post_id                                 18311
# published                 2008-01-03 17:20:00
# author                                @Andrey
# flow                                     misc
# polling                                 False
# content_len                              3291
# title          В чем суть проекта Vladelia.ru
# comments                                   64
# favs                                        1
# views                                     141
# votes_plus                                 17
# votes_minus                                20
# year                                     2008
# month                                       1
# day                                         3
# dayofweek                                   4
# hour                                       17
#
#                                                         8       \
# url                           https://habrahabr.ru/post/31352/
# domain                                            habrahabr.ru
# post_id                                                  31352
# published                                  2008-01-03 22:54:00
# author                                              @kvladimir
# flow                                                   develop
# polling                                                  False
# content_len                                               1953
# title        Подтверждено: Wikia Search запускается в понед...
# comments                                                    23
# favs                                                         2
# views                                                      208
# votes_plus                                                  21
# votes_minus                                                  3
# year                                                      2008
# month                                                        1
# day                                                          3
# dayofweek                                                    4
# hour                                                        22
#
#                                                        9       ...  \
# url                          https://habrahabr.ru/post/18314/  ...
# domain                                           habrahabr.ru  ...
# post_id                                                 18314  ...
# published                                 2008-01-03 23:56:00  ...
# author                                                  @lvea  ...
# flow                                                  develop  ...
# polling                                                 False  ...
# content_len                                              3712  ...
# title        Mobile 2.0 Выбор предпочтительного способа связи  ...
# comments                                                    6  ...
# favs                                                        1  ...
# views                                                     401  ...
# votes_plus                                                  2  ...
# votes_minus                                                 0  ...
# year                                                     2008  ...
# month                                                       1  ...
# day                                                         3  ...
# dayofweek                                                   4  ...
# hour                                                       23  ...
#
#                                                         134127  \
# url                          https://habrahabr.ru/post/314068/
# domain                                            habrahabr.ru
# post_id                                                 314068
# published                                  2016-10-31 19:53:00
# author                                                 @plan_A
# flow                                                   develop
# polling                                                  False
# content_len                                              13905
# title        ASO оптимизация. Составление семантического яд...
# comments                                                    16
# favs                                                        53
# views                                                     5900
# votes_plus                                                  13
# votes_minus                                                  0
# year                                                      2016
# month                                                       10
# day                                                         31
# dayofweek                                                    1
# hour                                                        19
#
#                                                        134128  \
# url                         https://habrahabr.ru/post/314078/
# domain                                           habrahabr.ru
# post_id                                                314078
# published                                 2016-10-31 19:54:00
# author                                      @semen_grinshtein
# flow                                               management
# polling                                                 False
# content_len                                             13832
# title        Как Windows NT стала «убийцей» Novell NetWare OS
# comments                                                   31
# favs                                                       32
# views                                                   16700
# votes_plus                                                 40
# votes_minus                                                 0
# year                                                     2016
# month                                                      10
# day                                                        31
# dayofweek                                                   1
# hour                                                       19
#
#                                                         134129  \
# url                          https://habrahabr.ru/post/314040/
# domain                                            habrahabr.ru
# post_id                                                 314040
# published                                  2016-10-31 20:01:00
# author                                              @MACROSCOP
# flow                                                   develop
# polling                                                  False
# content_len                                               8493
# title        Как найти вектор развития программного продукт...
# comments                                                    12
# favs                                                        38
# views                                                     2900
# votes_plus                                                   6
# votes_minus                                                  0
# year                                                      2016
# month                                                       10
# day                                                         31
# dayofweek                                                    1
# hour                                                        20
#
#                                                         134130  \
# url                          https://habrahabr.ru/post/314082/
# domain                                            habrahabr.ru
# post_id                                                 314082
# published                                  2016-10-31 20:29:00
# author                                              @alexeev_n
# flow                                                management
# polling                                                  False
# content_len                                               4529
# title        Почему в очередной раз проваливается внедрение...
# comments                                                    30
# favs                                                        36
# views                                                     4500
# votes_plus                                                  10
# votes_minus                                                 14
# year                                                      2016
# month                                                       10
# day                                                         31
# dayofweek                                                    1
# hour                                                        20
#
#                                                         134131  \
# url                          https://habrahabr.ru/post/313960/
# domain                                            habrahabr.ru
# post_id                                                 313960
# published                                  2016-10-31 21:08:00
# author                                              @Nuteralie
# flow                                                management
# polling                                                  False
# content_len                                               7104
# title        Большое количество людей в опенспейсе мешает с...
# comments                                                    82
# favs                                                        44
# views                                                    18500
# votes_plus                                                  36
# votes_minus                                                  4
# year                                                      2016
# month                                                       10
# day                                                         31
# dayofweek                                                    1
# hour                                                        21
#
#                                                        134132  \
# url          https://habrahabr.ru/company/mailru/blog/314014/
# domain                                           habrahabr.ru
# post_id                                                314014
# published                                 2016-10-31 21:45:00
# author                                                    NaN
# flow                                                  develop
# polling                                                 False
# content_len                                             56033
# title                          Парсинг JSON — это минное поле
# comments                                                   58
# favs                                                      347
# views                                                   35500
# votes_plus                                                164
# votes_minus                                                 6
# year                                                     2016
# month                                                      10
# day                                                        31
# dayofweek                                                   1
# hour                                                       21
#
#                                                         134133  \
# url                          https://geektimes.ru/post/282086/
# domain                                            geektimes.ru
# post_id                                                 282086
# published                                  2016-10-31 22:44:00
# author                                                  @marks
# flow                                                       NaN
# polling                                                  False
# content_len                                               5504
# title        Заработала система раннего предупреждения НАСА...
# comments                                                    52
# favs                                                        16
# views                                                    12900
# votes_plus                                                  22
# votes_minus                                                  0
# year                                                      2016
# month                                                       10
# day                                                         31
# dayofweek                                                    1
# hour                                                        22
#
#                                                         134134  \
# url                          https://geektimes.ru/post/282090/
# domain                                            geektimes.ru
# post_id                                                 282090
# published                                  2016-10-31 23:26:00
# author                                               @Shapelez
# flow                                                       NaN
# polling                                                  False
# content_len                                               2883
# title        Арзамасский городской суд постановил заблокиро...
# comments                                                    16
# favs                                                        14
# views                                                    15800
# votes_plus                                                  28
# votes_minus                                                  4
# year                                                      2016
# month                                                       10
# day                                                         31
# dayofweek                                                    1
# hour                                                        23
#
#                                                         134135  \
# url                          https://geektimes.ru/post/282092/
# domain                                            geektimes.ru
# post_id                                                 282092
# published                                  2016-10-31 23:52:00
# author                                               @ragequit
# flow                                                       NaN
# polling                                                  False
# content_len                                               5735
# title        Медиа-коммуникационный союз планирует внести в...
# comments                                                    47
# favs                                                        14
# views                                                    15000
# votes_plus                                                  20
# votes_minus                                                  0
# year                                                      2016
# month                                                       10
# day                                                         31
# dayofweek                                                    1
# hour                                                        23
#
#                                                         134136
# url                          https://habrahabr.ru/post/314088/
# domain                                            habrahabr.ru
# post_id                                                 314088
# published                                  2016-10-31 23:56:00
# author                                                  @Mgrin
# flow                                                   develop
# polling                                                  False
# content_len                                               9359
# title        mgr-forms-react: Простой компонент для простей...
# comments                                                     4
# favs                                                        35
# views                                                     3100
# votes_plus                                                  12
# votes_minus                                                  1
# year                                                      2016
# month                                                       10
# day                                                         31
# dayofweek                                                    1
# hour                                                        23
#
# [19 rows x 134137 columns]

# %% [markdown]
# -----
# Теперь Ваша очередь. В каждом пункте предлагается построить картинку и с ее помощью ответить на вопрос в [форме](https://docs.google.com/forms/d/e/1FAIpQLSf3b5OG8zX_nLQBQ-t20c6M5Auz-VUL-yxj8Fm9_o_XWDBTrg/viewform?c=0&w=1). Конечно, можно попытаться ответить на все вопросы только с Pandas, без картинок, но мы советуем Вам потренироваться строить (красивые) визуализации.

# %% [markdown]
# ## 1\. В каком месяце (и какого года) было больше всего публикаций?
#
# * март 2016
# * март 2015
# * апрель 2015
# * апрель 2016

# %%
df.groupby(['year', 'month']).size().plot(kind='bar', figsize=(20, 10), fontsize=10, rot=90);

# %%
df.groupby(['year', 'month']).size().idxmax()
# Out:
# (2015, 3)

# %% [markdown]
# ## 2\. Проанализируйте публикации в месяце из предыдущего вопроса
#
# Выберите один или несколько вариантов:
#
# * Один или несколько дней сильно выделяются из общей картины
# * На хабре _всегда_ больше статей, чем на гиктаймсе
# * По субботам на гиктаймс и на хабрахабр публикуют примерно одинаковое число статей
#
# Подсказки: постройте график зависимости числа публикаций от дня; используйте параметр `hue`; не заморачивайтесь сильно с ответами и не ищите скрытого смысла :)

# %%
temp_df = df[(df['year'] == 2015) & (df['month'] == 3)]

# %%
temp_df.groupby(['day', 'dayofweek']).size().plot(kind='bar', fontsize=8);

# %%
temp_df.groupby('domain').size().plot(kind='bar', fontsize=8);

# %%
sns.set(rc={'figure.figsize':(20,10)})
sns.countplot(x='day', hue='domain', data=temp_df);

# %% [markdown]
# ## 3\. Когда лучше всего публиковать статью?
#
# * Больше всего просмотров набирают статьи, опубликованные в 12 часов дня
# * У опубликованных в 10 утра постов больше всего комментариев
# * Больше всего просмотров набирают статьи, опубликованные в 6 часов утра
# * Максимальное число комментариев на гиктаймсе набрала статья, опубликованная в 9 часов вечера
# * На хабре дневные статьи комментируют чаще, чем вечерние

# %%
df.groupby('hour')['views'].mean().plot(kind='bar');

# %%
temp_df.groupby('hour')['comments'].mean().plot(kind='bar');

# %%
df.iloc[df[df['domain'] == 'geektimes.ru']['comments'].idxmax()]
# Out:
# url            https://geektimes.ru/post/123157/
# domain                              geektimes.ru
# post_id                                   123157
# published                    2011-07-01 02:35:00
# author                                  @Dottore
# flow                                         NaN
# polling                                    False
# content_len                                 2158
# title           Как раздавать инвайты на Google+
# comments                                    2266
# favs                                          24
# views                                      15300
# votes_plus                                   226
# votes_minus                                   55
# year                                        2011
# month                                          7
# day                                            1
# dayofweek                                      5
# hour                                           2
# Name: 38763, dtype: object

# %% [markdown]
# ## 4\. Кого из топ-20 авторов чаще всего минусуют?
#
# * @Mordatyj
# * @Mithgol
# * @alizar
# * @ilya42

# %%
top = df.groupby('author').size().sort_values(ascending=False).head(20).index

# %%
top
# Out:
# Index(['@alizar', '@marks', '@SLY_G', '@ivansychev', '@semen_grinshtein',
#        '@jeston', '@aleksandrit', '@XaocCPS', '@Mithgol', '@Mordatyj',
#        '@Shapelez', '@ilya42', '@atomlib', '@ragequit', '@Tylerskald',
#        '@andorro', '@jasiejames', '@lozga', '@Sterhel', '@Jeditobe'],
#       dtype='object', name='author')

# %%
df.groupby('author')['votes_minus'].mean()[top].sort_values()
# Out:
# author
# @semen_grinshtein     1.167378
# @jasiejames           1.516432
# @lozga                2.420000
# @ivansychev           2.498519
# @marks                3.834997
# @ragequit             4.018018
# @SLY_G                4.276947
# @atomlib              4.407982
# @jeston               4.831917
# @Shapelez             5.196998
# @Tylerskald           5.518519
# @ilya42               6.216797
# @Mordatyj             7.471455
# @alizar               7.928191
# @Sterhel              9.350785
# @aleksandrit          9.974643
# @andorro             13.654676
# @XaocCPS             15.286913
# @Jeditobe            16.491713
# @Mithgol             20.481081
# Name: votes_minus, dtype: float64

# %% [markdown]
# ## 5\. Сравните субботы и понедельники
#
# Правда ли, что по субботам авторы пишут в основном днём, а по понедельникам — в основном вечером?

# %%
sns.countplot(x='hour', hue='dayofweek', data=df[df['dayofweek'].isin([1, 6])]);
